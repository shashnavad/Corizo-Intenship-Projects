# %%
# !pip install -q mediapipe

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn as sk
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from mediapipe.tasks import python
from mediapipe.tasks.python import text

# %%
df = pd.read_csv('/Users/prathamgupta/Desktop/trainingLabeled.csv')
df
# Out:
#      Top100Year            SongTitle                      Artist  \
# 0          2014           West Coast                Lana Del Rey
# 1          2014            Automatic             Miranda Lambert
# 2          2014            Bartender             Lady Antebellum
# 3          2014    Beat Of The Music              Brett Eldredge
# 4          2014   Habits (Stay High)                     Tove Lo
# ..          ...                  ...                         ...
# 637        2023                Jaded                 Miley Cyrus
# 638        2023  Boy's A Liar, Pt. 2  PinkPantheress & Ice Spice
# 639        2023               Snooze                         SZA
# 640        2023         Need A Favor                  Jelly Roll
# 641        2023           Area Codes                      Kaliii
#
#      LyricsStatus                                             Lyrics  \
# 0            True  I can see my baby swingin'\nOoh baby baby bae,...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 642 entries, 0 to 641
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Top100Year    642 non-null    int64
#  1   SongTitle     642 non-null    object
#  2   Artist        642 non-null    object
#  3   LyricsStatus  642 non-null    bool
#  4   Lyrics        642 non-null    object
#  5   ReleaseYear   642 non-null    object
#  6   Genre         642 non-null    object
#  7   Label         642 non-null    object
# dtypes: bool(1), int64(1), object(6)
# memory usage: 35.9+ KB

# %%
df = df[df['LyricsStatus'] == True]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 642 entries, 0 to 641
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Top100Year    642 non-null    int64
#  1   SongTitle     642 non-null    object
#  2   Artist        642 non-null    object
#  3   LyricsStatus  642 non-null    bool
#  4   Lyrics        642 non-null    object
#  5   ReleaseYear   642 non-null    object
#  6   Genre         642 non-null    object
#  7   Label         642 non-null    object
# dtypes: bool(1), int64(1), object(6)
# memory usage: 40.8+ KB

# %%
# # Extract the song title and lyrics from the DataFrame
# title = df["SongTitle"][0]
# lyrics = df["Lyrics"][0]

# # Print out the song title and lyrics
# print(f"{title}: {lyrics}")

# %%
# df["Lyrics"][600]

# %%
# import nltk
# nltk.download('averaged_perceptron_tagger')
# nltk.download('words')

# from nltk.corpus import words

# english_words = set(words.words())
# english_words_array = list(english_words_set)
# print(english_words)

# %%
# print(type(english_words))

# %%
# dictionary = english_words
# word = input("Enter a word: ")
# if word not in dictionary:
#     print(f"The word {word} is not found in the dictionary.")
# else:
#     print(f"The word {word} is found in the dictionary.")

# %%
# import csv
# import nltk
# from nltk.corpus import words as nltk_words

# nltk.download('words')

# def is_english_word(word):
#     return word.lower() in nltk_words.words()

# def count_non_english_words(csv_file):
#     non_english_word_count = 0
#     with open(csv_file, 'r', encoding='utf-8') as file:
#         reader = csv.DictReader(file)
#         for row in reader:
#             lyrics = row['Lyrics']
#             # Split lyrics into words and check each word
#             for word in lyrics.split():
#                 if not is_english_word(word):
#                     print(word)
#                     non_english_word_count += 1
#     return non_english_word_count

# def main():
#     csv_file = '/Users/prathamgupta/Desktop/trainingLabeled.csv'  # Replace 'your_csv_file.csv' with your CSV file path
#     non_english_word_count = count_non_english_words(csv_file)
#     print("Number of non-English words in the CSV file:", non_english_word_count)

# if __name__ == "__main__":
#     main()

# %%
# import nltk
# from nltk.corpus import words

# # Load the list of words from the CSV file
# words_list = []
# with open("/Users/prathamgupta/Desktop/trainingLabeled.csv", "r") as f:
#     for line in f:
#         word = line.strip()
#         if word != "":
#             words_list.append(word)

# # Use the correct_spelling function to standardize the spellings
# standardized_words = [nltk.correct_spelling(word) for word in words_list]

# # Print the standardized words
# print(standardized_words)

# %%
# !pip install -q mediapipe

# %%
# !wget -O classifier.tflite -q https://storage.googleapis.com/mediapipe-models/text_classifier/bert_classifier/float32/1/bert_classifier.tflite

# %%
# Define the input text that you wants the model to classify.
# lyrics = df["Lyrics"]
# for i in range(len(lyrics))
INPUT_TEXT = df["Lyrics"][4]
print(INPUT_TEXT)
# Out:
# I eat my dinner in my bathtub
# Then I go to sex clubs
# Watching freaky people getting it on
# It doesn't make me nervous
# If anything, I'm restless
# Yeah, I've been around, and I've seen it all
# I get home, I got the munchies
# Binge on all my Twinkies
# Throw up in the 'tub, then I go to sleep
# And I drank up all my money
# Dazed and kinda lonely
# You're gone, and I gotta stay high all the time
# To keep you off my mind
# Ooh-ooh, ooh-ooh
# High all the time to keep you off my mind
# Ooh-ooh, ooh-ooh
# Spend my days locked in a haze
# Trying to forget you, babe, I fall back down
# Gotta stay high all my life to forget I'm missing you
# Ooh-ooh, ooh-ooh
# Pick up daddies at the playground
# How I spend my daytime
# Loosen up the frown, make them feel alive
# I make it fast and greasy
# I'm numb, and way too easy
# You're gone, and I gotta stay high all the time
# To keep you off my mind
# Ooh-ooh, ooh-ooh
# High all the time to keep you off my mind
# Ooh-ooh, ooh-ooh
# ...

# %%
# STEP 1: Import the necessary modules.
# from mediapipe.tasks import python
# from mediapipe.tasks.python import text

# STEP 2: Create an TextClassifier object.
base_options = python.BaseOptions(model_asset_path="classifier.tflite")
options = text.TextClassifierOptions(base_options=base_options, max_results=10, score_threshold=0.24)
classifier = text.TextClassifier.create_from_options(options)

# STEP 3: Classify the input text.
classification_result = classifier.classify(INPUT_TEXT)

# STEP 4: Process the classification result. In this case, print out the most likely category.
top_category = classification_result.classifications[0].categories[0]
print(f'{top_category.category_name} ({top_category.score:.2f})')
# Out:
# negative (0.92)

# %%
pip install mediapipe-model-maker
from mediapipe_model_maker import image_classifier
model = image_classifier.ImageClassifier.create(
    train_data = train_data,
    validation_data = validation_data,
    options=options,
)
# Out:
#   File "<ipython-input-37-9ffa1c4ef4a7>", line 1
#     pip install mediapipe-model-maker
#         ^
# SyntaxError: invalid syntax

# %%
text.TextClassifierOptions??
# Out:
# Init signature:
# text.TextClassifierOptions(
#     base_options: mediapipe.tasks.python.core.base_options.BaseOptions,
#     display_names_locale: Union[str, NoneType] = None,
#     max_results: Union[int, NoneType] = None,
#     score_threshold: Union[float, NoneType] = None,
#     category_allowlist: Union[List[str], NoneType] = None,
#     category_denylist: Union[List[str], NoneType] = None,
# ) -> None
# Source:
# class TextClassifierOptions:
#   """Options for the text classifier task.
#
#   Attributes:
#     base_options: Base options for the text classifier task.
#     display_names_locale: The locale to use for display names specified through
#       the TFLite Model Metadata.
#     max_results: The maximum number of top-scored classification results to
#       return.
#     score_threshold: Overrides the ones provided in the model metadata. Results
#       below this value are rejected.
#     category_allowlist: Allowlist of category names. If non-empty,
# ...
